# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\user\\Downloads\\Ogoo_Vizualization\\covid-19_data_Nigeria.csv")
data.head()
# Out:
#    Country Region ObservationDate  Confirmed  Deaths  Recovered  \
# 0  Nigeria  South      01/01/2020          1       0          0
# 1  Nigeria  South      01/02/2020          1       0          0
# 2  Nigeria  South      01/03/2020          2       0          0
# 3  Nigeria  South      01/04/2020          4       1          0
# 4  Nigeria  South      01/05/2020          5       1          0
#
#    month_since_first_confirmed  Avg_age_of_death  Avg_age
# 0                            1                 0       67
# 1                            2                 0       78
# 2                            3                 0       89
# 3                            4                60       78
# 4                            5                67       55

# %%
data.describe()
# Out:
#         Confirmed      Deaths   Recovered  month_since_first_confirmed  \
# count   50.000000   50.000000   50.000000                    50.000000
# mean   143.660000   29.400000   34.680000                    13.000000
# std    183.342838   36.848282   35.210991                     7.284314
# min      1.000000    0.000000    0.000000                     1.000000
# 25%     13.750000    4.000000    2.000000                     7.000000
# 50%     63.500000   17.000000   33.500000                    13.000000
# 75%    142.500000   40.000000   53.750000                    19.000000
# max    700.000000  190.000000  120.000000                    25.000000
#
#        Avg_age_of_death    Avg_age
# count         50.000000  50.000000
# mean          66.280000  71.060000
# std           24.310945   8.454947
# min            0.000000  55.000000
# 25%           65.250000  65.250000
# 50%           76.000000  71.500000
# 75%           78.000000  76.750000
# max           98.000000  89.000000

# %% [markdown]
# Average age of confirmed cases

# %%
sns.set()
sns.distplot(data['Avg_age'], kde=False,  color='b')

plt.show()
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Majority of confirmed cases is between the ages of 65-75 years.

# %% [markdown]
# The majority of confirmed death is between the ages of 75 and 80 years. According to the graph below

# %%
sns.set()
sns.distplot(data['Avg_age_of_death'], kde=False,  color='b'  )

plt.show()

# %%
sns.relplot(x='month_since_first_confirmed', y='Confirmed', kind='line', data=data, hue='Region', ci=None)

# %% [markdown]
# Comparing confirmed deaths and recovered

# %%
sns.relplot(x='Confirmed', y='Deaths', kind='scatter', data=data)
plt.show()

# %% [markdown]
# From the graph above, we can confirm that the more confiirmed cases, the more death.

# %%
sns.relplot(x='Confirmed', y='Deaths', kind='scatter', data=data, hue='Region')
plt.show()

# %%
sns.jointplot(x='Confirmed', y='Deaths', kind='scatter', data=data, hue='Region')
plt.show()

# %%
sns.jointplot(x='Confirmed', y='Deaths', kind='reg', data=data)
plt.show()

# %%
sns.jointplot(x='Confirmed', y='Deaths', kind='kde', data=data)
plt.show()
